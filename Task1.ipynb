# %% [markdown]
# <a href="https://colab.research.google.com/github/sambslam/PitchXAI-Assignment/blob/main/Task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sambslam/PitchXAI-Assignment.git
# %cd PitchXAI-Assignment
# Out:
# Cloning into 'PitchXAI-Assignment'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 34 (delta 14), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (34/34), 9.24 KiB | 1.85 MiB/s, done.
# Resolving deltas: 100% (14/14), done.
# /content/PitchXAI-Assignment/task1-voice-pipeline
