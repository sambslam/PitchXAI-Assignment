# %% [markdown]
# <a href="https://colab.research.google.com/github/sambslam/PitchXAI-Assignment/blob/main/Task3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/sambslam/PitchXAI-Assignment.git
# %cd PitchXAI-Assignment/task3-broswer-agent
# Out:
# Cloning into 'PitchXAI-Assignment'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 18 (delta 5), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (18/18), 5.49 KiB | 5.49 MiB/s, done.
# Resolving deltas: 100% (5/5), done.
# /content/PitchXAI-Assignment/task3-broswer-agent

# %%
# !git config --global user.email "samarthlamba3@gmail.com"
# !git config --global user.name "Samarth Lamba"
